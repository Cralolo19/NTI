# %%
import numpy as np
import csv

# %%
file0 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_1em2_to_1em1.txt", delimiter=',')
file1 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_1em2_to_1em1.txt", delimiter=',')[1:]
file2 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_1em1_to_2em1.txt", delimiter=',')[1:]
file3 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_2em1_to_3em1.txt", delimiter=',')[1:]
file4 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_3em1_to_4em1.txt", delimiter=',')[1:]
file5 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_4em1_to_5em1.txt", delimiter=',')[1:]
file6 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_5em1_to_6em1.txt", delimiter=',')[1:]
file7 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_6em1_to_7em1.txt", delimiter=',')[1:]
file8 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_7em1_to_8em1.txt", delimiter=',')[1:]
file9 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_8em1_to_9em1.txt", delimiter=',')[1:]
file10 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_9em1_to_1.txt", delimiter=',')[1:]
file11 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_1_to_5.txt", delimiter=',')[1:]
file12 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_5_to_10.txt", delimiter=',')[1:]
file13 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_10_to_20.txt", delimiter=',')[1:]
file14 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_20_to_40.txt", delimiter=',')[1:]
file15 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_40_to_60.txt", delimiter=',')[1:]
file16 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_60_to_80.txt", delimiter=',')[1:]
file17 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_80_to_100.txt", delimiter=',')[1:]
file18 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_100_to_140.txt", delimiter=',')[1:]
file19 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_140_to_180.txt", delimiter=',')[1:]
file20 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_180_to_220.txt", delimiter=',')[1:]
file21 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_220_to_300.txt", delimiter=',')[1:]
file22 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_300_to_380.txt", delimiter=',')[1:]
file23 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_380_to_500.txt", delimiter=',')[1:]
file24 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_500_to_620.txt", delimiter=',')[1:]
file25 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_620_to_740.txt", delimiter=',')[1:]
file26 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_740_to_900.txt", delimiter=',')[1:]
file27 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_900_to_1060.txt", delimiter=',')[1:]
file28 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_1060_to_1300.txt", delimiter=',')[1:]
file29 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_1300_to_1540.txt", delimiter=',')[1:]
file30 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_1540_to_1900.txt", delimiter=',')[1:]
file31 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_1900_to_2260.txt", delimiter=',')[1:]
file32 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_2260_to_2800.txt", delimiter=',')[1:]
file33 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_2800_to_3500.txt", delimiter=',')[1:]
file34 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_3500_to_4500.txt", delimiter=',')[1:]
file35 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_4500_to_6000.txt", delimiter=',')[1:]
file36 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_6000_to_8000.txt", delimiter=',')[1:]
file37 = np.loadtxt("vmu_to_vmu_mu+_mu-_coh_W_[KN]_xsec_8000_to_10000.txt", delimiter=',')[1:]
