# %%
import numpy as np
import csv

# %%
file0 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_0_to_1em2.txt", delimiter=',')
file1 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_1em2_to_1em1.txt", delimiter=',')[1:]
file2 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_1em1_to_2em1.txt", delimiter=',')[1:]
file3 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_2em1_to_3em1.txt", delimiter=',')[1:]
file4 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_3em1_to_4em1.txt", delimiter=',')[1:]
file5 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_4em1_to_5em1.txt", delimiter=',')[1:]
file6 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_5em1_to_6em1.txt", delimiter=',')[1:]
file7 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_6em1_to_7em1.txt", delimiter=',')[1:]
file8 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_7em1_to_8em1.txt", delimiter=',')[1:]
file9 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_8em1_to_9em1.txt", delimiter=',')[1:]
file10 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_9em1_to_1.txt", delimiter=',')[1:]
file11 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_1_to_5.txt", delimiter=',')[1:]
file12 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_5_to_10.txt", delimiter=',')[1:]
file13 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_10_to_20.txt", delimiter=',')[1:]
file14 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_20_to_40.txt", delimiter=',')[1:]
file15 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_40_to_60.txt", delimiter=',')[1:]
file16 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_60_to_80.txt", delimiter=',')[1:]
file17 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_80_to_100.txt", delimiter=',')[1:]
file18 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_100_to_140.txt", delimiter=',')[1:]
file19 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_140_to_180.txt", delimiter=',')[1:]
file20 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_180_to_220.txt", delimiter=',')[1:]
file21 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_220_to_300.txt", delimiter=',')[1:]
file22 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_300_to_380.txt", delimiter=',')[1:]
file23 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_380_to_500.txt", delimiter=',')[1:]
file24 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_500_to_620.txt", delimiter=',')[1:]
file25 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_620_to_740.txt", delimiter=',')[1:]
file26 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_740_to_900.txt", delimiter=',')[1:]
file27 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_900_to_1060.txt", delimiter=',')[1:]
file28 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_1060_to_1300.txt", delimiter=',')[1:]
file29 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_1300_to_1540.txt", delimiter=',')[1:]
file30 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_1540_to_1900.txt", delimiter=',')[1:]
file31 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_1900_to_2260.txt", delimiter=',')[1:]
file32 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_2260_to_2800.txt", delimiter=',')[1:]
file33 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_2800_to_3500.txt", delimiter=',')[1:]
file34 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_3500_to_4500.txt", delimiter=',')[1:]
file35 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_4500_to_6000.txt", delimiter=',')[1:]
file36 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_6000_to_8000.txt", delimiter=',')[1:]
file37 = np.loadtxt("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec_8000_to_10000.txt", delimiter=',')[1:]

# %%
all_files1 = np.concatenate((file0, file1, file2, file3, file4, file5, file6, file7, file8, file9, file10))
all_files2 = np.concatenate((file11,file12,file13, file14, file15, file16, file17, file18, file19, file20))
all_files3 = np.concatenate((file21,file22,file23, file24, file25, file26, file27, file28, file29, file30))
all_files4 = np.concatenate((file31,file32,file33, file34, file35, file36, file37))

# %%
all_files = np.concatenate((all_files1, all_files2, all_files3, all_files4))

# %%
with open("vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(all_files)
