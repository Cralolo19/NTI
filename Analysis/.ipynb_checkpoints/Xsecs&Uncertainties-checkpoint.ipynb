# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import matplotlib

plt.style.use('sty.mplstyle')

# %% [markdown]
# # Upload Cross Sections for different Form Factors & materials

# %%
Enu = np.loadtxt('../csv/CrossSections/ve_to_ve_e+_e-_xsec/Coherent/Tungsten/WS/ve_to_ve_e+_e-_coh_W_[WS]_xsec', delimiter=',', usecols=0) # GeV

####################################################################################################################
############################ Cross Sections for the process: ve -> ve e+ e- ########################################
####################################################################################################################
Xsec_ve_e_e_coh_W_WS = np.loadtxt('../csv/CrossSections/ve_to_ve_e+_e-_xsec/Coherent/Tungsten/WS/ve_to_ve_e+_e-_coh_W_[WS]_xsec', delimiter=',', usecols=1) # fb
Xsec_ve_e_e_coh_W_H1 = np.loadtxt('../csv/CrossSections/ve_to_ve_e+_e-_xsec/Coherent/Tungsten/Helmv1/ve_to_ve_e+_e-_coh_W_[H1]_xsec', delimiter=',', usecols=1) # fb
Xsec_ve_e_e_coh_W_H2 = np.loadtxt('../csv/CrossSections/ve_to_ve_e+_e-_xsec/Coherent/Tungsten/Helmv2/ve_to_ve_e+_e-_coh_W_[H2]_xsec', delimiter=',', usecols=1) # fb
Xsec_ve_e_e_coh_W_KN = np.loadtxt('../csv/CrossSections/ve_to_ve_e+_e-_xsec/Coherent/Tungsten/KN/ve_to_ve_e+_e-_coh_W_[KN]_xsec', delimiter=',', usecols=1) # fb
Xsec_ve_e_e_coh_W_adKN = np.loadtxt('../csv/CrossSections/ve_to_ve_e+_e-_xsec/Coherent/Tungsten/adKN/ve_to_ve_e+_e-_coh_W_[adKN]_xsec', delimiter=',', usecols=1) # fb

####################################################################################################################
############################ Cross Sections for the process: ve -> ve mu+ mu- ########################################
####################################################################################################################
Xsec_ve_mu_mu_coh_W_WS = np.loadtxt('../csv/CrossSections/ve_to_ve_mu+_mu-_xec/Coherent/Tungsten/WS/ve_to_ve_mu+_mu-_coh_W_[WS]_xsec', delimiter=',', usecols=1) # fb
Xsec_ve_mu_mu_coh_W_H1 = np.loadtxt('../csv/CrossSections/ve_to_ve_mu+_mu-_xec/Coherent/Tungsten/Helmv1/ve_to_ve_mu+_mu-_coh_W_[H1]_xsec', delimiter=',', usecols=1) # fb
Xsec_ve_mu_mu_coh_W_H2 = np.loadtxt('../csv/CrossSections/ve_to_ve_mu+_mu-_xec/Coherent/Tungsten/Helmv2/ve_to_ve_mu+_mu-_coh_W_[H2]_xsec', delimiter=',', usecols=1) # fb
Xsec_ve_mu_mu_coh_W_KN = np.loadtxt('../csv/CrossSections/ve_to_ve_mu+_mu-_xec/Coherent/Tungsten/KN/ve_to_ve_mu+_mu-_coh_W_[KN]_xsec', delimiter=',', usecols=1) # fb
Xsec_ve_mu_mu_coh_W_adKN = np.loadtxt('../csv/CrossSections/ve_to_ve_mu+_mu-_xec/Coherent/Tungsten/adKN/ve_to_ve_mu+_mu-_coh_W_[adKN]_xsec', delimiter=',', usecols=1) # fb

####################################################################################################################
############################ Cross Sections for the process: ve -> vmu mu+ e- ########################################
####################################################################################################################
Xsec_vmu_mu_e_coh_W_WS = np.loadtxt('../csv/CrossSections/ve_to_vmu_mu+_e-_xsec/Coherent/Tungsten/WS/ve_to_vmu_mu+_e-_coh_W_[WS]_xsec', delimiter=',', usecols=1) # fb
Xsec_vmu_mu_e_coh_W_H1 = np.loadtxt('../csv/CrossSections/ve_to_vmu_mu+_e-_xsec/Coherent/Tungsten/Helmv1/ve_to_vmu_mu+_e-_coh_W_[H1]_xsec', delimiter=',', usecols=1) # fb
Xsec_vmu_mu_e_coh_W_H2 = np.loadtxt('../csv/CrossSections/ve_to_vmu_mu+_e-_xsec/Coherent/Tungsten/Helmv2/ve_to_vmu_mu+_e-_coh_W_[H2]_xsec', delimiter=',', usecols=1) # fb
Xsec_vmu_mu_e_coh_W_KN = np.loadtxt('../csv/CrossSections/ve_to_vmu_mu+_e-_xsec/Coherent/Tungsten/KN/ve_to_vmu_mu+_e-_coh_W_[KN]_xsec', delimiter=',', usecols=1) # fb
Xsec_vmu_mu_e_coh_W_adKN = np.loadtxt('../csv/CrossSections/ve_to_vmu_mu+_e-_xsec/Coherent/Tungsten/adKN/ve_to_vmu_mu+_e-_coh_W_[adKN]_xsec', delimiter=',', usecols=1) # fb

####################################################################################################################
############################ Cross Sections for the process: ve -> vtau tau+ e- ########################################
####################################################################################################################
Xsec_vtau_tau_e_coh_W_WS = np.loadtxt('../csv/CrossSections/ve_to_vtau_tau+_e-_xsec/Coherent/Tungsten/WS/ve_to_vtau_tau+_e-_coh_W_[WS]_xsec', delimiter=',', usecols=1) # fb
Xsec_vtau_tau_e_coh_W_H1 = np.loadtxt('../csv/CrossSections/ve_to_vtau_tau+_e-_xsec/Coherent/Tungsten/Helmv1/ve_to_vtau_tau+_e-_coh_W_[H1]_xsec', delimiter=',', usecols=1) # fb
Xsec_vtau_tau_e_coh_W_H2 = np.loadtxt('../csv/CrossSections/ve_to_vtau_tau+_e-_xsec/Coherent/Tungsten/Helmv2/ve_to_vtau_tau+_e-_coh_W_[H2]_xsec', delimiter=',', usecols=1) # fb
Xsec_vtau_tau_e_coh_W_KN = np.loadtxt('../csv/CrossSections/ve_to_vtau_tau+_e-_xsec/Coherent/Tungsten/KN/ve_to_vtau_tau+_e-_coh_W_[KN]_xsec', delimiter=',', usecols=1) # fb
Xsec_vtau_tau_e_coh_W_adKN = np.loadtxt('../csv/CrossSections/ve_to_vtau_tau+_e-_xsec/Coherent/Tungsten/adKN/ve_to_vtau_tau+_e-_coh_W_[adKN]_xsec', delimiter=',', usecols=1) # fb

# %%
####################################################################################################################
########################### Cross Sections for the process: vmu -> ve e+ mu- #######################################
####################################################################################################################
Energy_ve_e_mu_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_ve_e+_mu-_xsec/Coherent/Argon/3pF/vmu_to_ve_e+_mu-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=0) # GeV
Xsec_ve_e_mu_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_ve_e+_mu-_xsec/Coherent/Argon/3pF/vmu_to_ve_e+_mu-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=1) # fb

Energy_ve_e_mu_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_ve_e+_mu-_xsec/Coherent/Argon/Helm/vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec', delimiter=',', usecols=0) # GeV
Xsec_ve_e_mu_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_ve_e+_mu-_xsec/Coherent/Argon/Helm/vmu_to_ve_e+_mu-_coh_Ar_[H]_xsec', delimiter=',', usecols=1) # fb

Energy_ve_e_mu_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_ve_e+_mu-_xsec/Coherent/Argon/KN/vmu_to_ve_e+_mu-_coh_Ar_[KN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_ve_e_mu_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_ve_e+_mu-_xsec/Coherent/Argon/KN/vmu_to_ve_e+_mu-_coh_Ar_[KN]_xsec', delimiter=',', usecols=1) # fb

Energy_ve_e_mu_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_ve_e+_mu-_xsec/Coherent/Argon/adKN/vmu_to_ve_e+_mu-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_ve_e_mu_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_ve_e+_mu-_xsec/Coherent/Argon/adKN/vmu_to_ve_e+_mu-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=1) # fb

####################################################################################################################
########################### Cross Sections for the process: vmu -> vmu e+ e- #######################################
####################################################################################################################
Energy_vmu_e_e_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_vmu_e+_e-_xsec/Coherent/Argon/3pF/vmu_to_vmu_e+_e-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_e_e_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_vmu_e+_e-_xsec/Coherent/Argon/3pF/vmu_to_vmu_e+_e-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_e_e_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_vmu_e+_e-_xsec/Coherent/Argon/Helm/vmu_to_vmu_e+_e-_coh_Ar_[H]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_e_e_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_vmu_e+_e-_xsec/Coherent/Argon/Helm/vmu_to_vmu_e+_e-_coh_Ar_[H]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_e_e_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_e+_e-_xsec/Coherent/Argon/KN/vmu_to_vmu_e+_e-_coh_Ar_[KN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_e_e_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_e+_e-_xsec/Coherent/Argon/KN/vmu_to_vmu_e+_e-_coh_Ar_[KN]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_e_e_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_e+_e-_xsec/Coherent/Argon/adKN/vmu_to_vmu_e+_e-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_e_e_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_e+_e-_xsec/Coherent/Argon/adKN/vmu_to_vmu_e+_e-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=1) # fb

####################################################################################################################
########################### Cross Sections for the process: vmu -> vmu mu+ mu- #####################################
####################################################################################################################
Energy_vmu_mu_mu_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_vmu_mu+_mu-_xsec/Coherent/Argon/3pF/vmu_to_vmu_mu+_mu-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_mu_mu_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_vmu_mu+_mu-_xsec/Coherent/Argon/3pF/vmu_to_vmu_mu+_mu-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_mu_mu_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_vmu_mu+_mu-_xsec/Coherent/Argon/Helm/vmu_to_vmu_mu+_mu-_coh_Ar_[H]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_mu_mu_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_vmu_mu+_mu-_xsec/Coherent/Argon/Helm/vmu_to_vmu_mu+_mu-_coh_Ar_[H]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_mu_mu_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_mu+_mu-_xsec/Coherent/Argon/KN/vmu_to_vmu_mu+_mu-_coh_Ar_[KN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_mu_mu_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_mu+_mu-_xsec/Coherent/Argon/KN/vmu_to_vmu_mu+_mu-_coh_Ar_[KN]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_mu_mu_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_mu+_mu-_xsec/Coherent/Argon/adKN/vmu_to_vmu_mu+_mu-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_mu_mu_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_mu+_mu-_xsec/Coherent/Argon/adKN/vmu_to_vmu_mu+_mu-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=1) # fb

####################################################################################################################
########################### Cross Sections for the process: vmu -> vmu tau+ tau- ###################################
####################################################################################################################
Energy_vmu_tau_tau_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_vmu_tau+_tau-_xsec/Coherent/Argon/3pF/vmu_to_vmu_tau+_tau-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_tau_tau_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_vmu_tau+_tau-_xsec/Coherent/Argon/3pF/vmu_to_vmu_tau+_tau-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_tau_tau_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_vmu_tau+_tau-_xsec/Coherent/Argon/Helm/vmu_to_vmu_tau+_tau-_coh_Ar_[H]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_tau_tau_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_vmu_tau+_tau-_xsec/Coherent/Argon/Helm/vmu_to_vmu_tau+_tau-_coh_Ar_[H]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_tau_tau_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_tau+_tau-_xsec/Coherent/Argon/KN/vmu_to_vmu_tau+_tau-_coh_Ar_[KN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_tau_tau_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_tau+_tau-_xsec/Coherent/Argon/KN/vmu_to_vmu_tau+_tau-_coh_Ar_[KN]_xsec', delimiter=',', usecols=1) # fb

Energy_vmu_tau_tau_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_tau+_tau-_xsec/Coherent/Argon/adKN/vmu_to_vmu_tau+_tau-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vmu_tau_tau_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_vmu_tau+_tau-_xsec/Coherent/Argon/adKN/vmu_to_vmu_tau+_tau-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=1) # fb

####################################################################################################################
########################### Cross Sections for the process: vmu -> vtau tau+ mu- ###################################
####################################################################################################################
Energy_vtau_tau_mu_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_vtau_tau+_mu-_xsec/Coherent/Argon/3pF/vmu_to_vtau_tau+_mu-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vtau_tau_mu_coh_Ar_3pF = np.loadtxt('../csv/CrossSections/vmu_to_vtau_tau+_mu-_xsec/Coherent/Argon/3pF/vmu_to_vtau_tau+_mu-_coh_Ar_[3pF]_xsec', delimiter=',', usecols=1) # fb

Energy_vtau_tau_mu_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_vtau_tau+_mu-_xsec/Coherent/Argon/Helm/vmu_to_vtau_tau+_mu-_coh_Ar_[H]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vtau_tau_mu_coh_Ar_Helm = np.loadtxt('../csv/CrossSections/vmu_to_vtau_tau+_mu-_xsec/Coherent/Argon/Helm/vmu_to_vtau_tau+_mu-_coh_Ar_[H]_xsec', delimiter=',', usecols=1) # fb

Energy_vtau_tau_mu_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_vtau_tau+_mu-_xsec/Coherent/Argon/KN/vmu_to_vtau_tau+_mu-_coh_Ar_[KN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vtau_tau_mu_coh_Ar_KN = np.loadtxt('../csv/CrossSections/vmu_to_vtau_tau+_mu-_xsec/Coherent/Argon/KN/vmu_to_vtau_tau+_mu-_coh_Ar_[KN]_xsec', delimiter=',', usecols=1) # fb

Energy_vtau_tau_mu_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_vtau_tau+_mu-_xsec/Coherent/Argon/adKN/vmu_to_vtau_tau+_mu-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=0) # GeV
Xsec_vtau_tau_mu_coh_Ar_adKN = np.loadtxt('../csv/CrossSections/vmu_to_vtau_tau+_mu-_xsec/Coherent/Argon/adKN/vmu_to_vtau_tau+_mu-_coh_Ar_[adKN]_xsec', delimiter=',', usecols=1) # fb

# %% [markdown]
# # Plot Cross Sections for Various Processes, Form Factors & materials

# %%
fig = plt.figure()
ax = fig.add_subplot()

####################################################################################################################
####################################### x-axis: GeV y-axis: cm^2/GeV ###############################################
####################################################################################################################
col = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']
ls = ['-', '--', ':', '-.']

########################### Add background to introduce the Form Factor Labels #####################################
ax.plot(Energy_ve_e_mu_coh_Ar_3pF[1:], 1e-39*Xsec_ve_e_mu_coh_Ar_3pF[1:]/Energy_ve_e_mu_coh_Ar_3pF[1:], color='black', ls=ls[0], lw=2, label='3pF', zorder=-100, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_ve_e_mu_coh_Ar_Helm[1:], 1e-39*Xsec_ve_e_mu_coh_Ar_Helm[1:]/Energy_ve_e_mu_coh_Ar_Helm[1:], color='black', ls=ls[1], lw=2, label='Helm', zorder=-100,  path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_ve_e_mu_coh_Ar_KN[1:], 1e-39*Xsec_ve_e_mu_coh_Ar_KN[1:]/Energy_ve_e_mu_coh_Ar_KN[1:], color='black', ls=ls[2], lw=2, label='KN', zorder=-100, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_ve_e_mu_coh_Ar_adKN[1:], 1e-39*Xsec_ve_e_mu_coh_Ar_adKN[1:]/Energy_ve_e_mu_coh_Ar_adKN[1:], color='black', ls=ls[3], lw=2, label='(ad.) KN', zorder=-100, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])


########################### Cross Sections for the process: vmu -> ve e+ mu- #######################################
ax.plot(Energy_ve_e_mu_coh_Ar_3pF[1:], 1e-39*Xsec_ve_e_mu_coh_Ar_3pF[1:]/Energy_ve_e_mu_coh_Ar_3pF[1:], color=col[0], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_ve_e_mu_coh_Ar_Helm[1:], 1e-39*Xsec_ve_e_mu_coh_Ar_Helm[1:]/Energy_ve_e_mu_coh_Ar_Helm[1:], color=col[0], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_ve_e_mu_coh_Ar_KN[1:], 1e-39*Xsec_ve_e_mu_coh_Ar_KN[1:]/Energy_ve_e_mu_coh_Ar_KN[1:], color=col[0], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_ve_e_mu_coh_Ar_adKN[1:], 1e-39*Xsec_ve_e_mu_coh_Ar_adKN[1:]/Energy_ve_e_mu_coh_Ar_adKN[1:], color=col[0], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

########################### Cross Sections for the process: vmu -> vmu e+ e- #######################################
ax.plot(Energy_vmu_e_e_coh_Ar_3pF[1:], 1e-39*Xsec_vmu_e_e_coh_Ar_3pF[1:]/Energy_vmu_e_e_coh_Ar_3pF[1:], color=col[1], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_e_e_coh_Ar_Helm[1:], 1e-39*Xsec_vmu_e_e_coh_Ar_Helm[1:]/Energy_vmu_e_e_coh_Ar_Helm[1:], color=col[1], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_e_e_coh_Ar_KN[1:], 1e-39*Xsec_vmu_e_e_coh_Ar_KN[1:]/Energy_vmu_e_e_coh_Ar_KN[1:], color=col[1], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_e_e_coh_Ar_adKN[1:], 1e-39*Xsec_vmu_e_e_coh_Ar_adKN[1:]/Energy_vmu_e_e_coh_Ar_adKN[1:], color=col[1], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

########################### Cross Sections for the process: vmu -> vmu mu+ mu- #####################################
ax.plot(Energy_vmu_mu_mu_coh_Ar_3pF, 1e-39*Xsec_vmu_mu_mu_coh_Ar_3pF/Energy_vmu_mu_mu_coh_Ar_3pF, color=col[2], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_mu_mu_coh_Ar_Helm, 1e-39*Xsec_vmu_mu_mu_coh_Ar_Helm/Energy_vmu_mu_mu_coh_Ar_Helm, color=col[2], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_mu_mu_coh_Ar_KN, 1e-39*Xsec_vmu_mu_mu_coh_Ar_KN/Energy_vmu_mu_mu_coh_Ar_KN, color=col[2], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_mu_mu_coh_Ar_adKN, 1e-39*Xsec_vmu_mu_mu_coh_Ar_adKN/Energy_vmu_mu_mu_coh_Ar_adKN, color=col[2], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

########################### Cross Sections for the process: vmu -> vmu tau+ tau- ###################################
ax.plot(Energy_vmu_tau_tau_coh_Ar_3pF[1:], 1e-39*Xsec_vmu_tau_tau_coh_Ar_3pF[1:]/Energy_vmu_tau_tau_coh_Ar_3pF[1:], color=col[3], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_tau_tau_coh_Ar_Helm[1:], 1e-39*Xsec_vmu_tau_tau_coh_Ar_Helm[1:]/Energy_vmu_tau_tau_coh_Ar_Helm[1:], color=col[3], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_tau_tau_coh_Ar_KN[1:], 1e-39*Xsec_vmu_tau_tau_coh_Ar_KN[1:]/Energy_vmu_tau_tau_coh_Ar_KN[1:], color=col[3], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vmu_tau_tau_coh_Ar_adKN[1:], 1e-39*Xsec_vmu_tau_tau_coh_Ar_adKN[1:]/Energy_vmu_tau_tau_coh_Ar_adKN[1:], color=col[3], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

########################### Cross Sections for the process: vmu -> vtau tau+ mu- ###################################
ax.plot(Energy_vtau_tau_mu_coh_Ar_3pF[1:], 1e-39*Xsec_vtau_tau_mu_coh_Ar_3pF[1:]/Energy_vtau_tau_mu_coh_Ar_3pF[1:], color=col[4], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vtau_tau_mu_coh_Ar_Helm[1:], 1e-39*Xsec_vtau_tau_mu_coh_Ar_Helm[1:]/Energy_vtau_tau_mu_coh_Ar_Helm[1:], color=col[4], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vtau_tau_mu_coh_Ar_KN[1:], 1e-39*Xsec_vtau_tau_mu_coh_Ar_KN[1:]/Energy_vtau_tau_mu_coh_Ar_KN[1:], color=col[4], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Energy_vtau_tau_mu_coh_Ar_adKN[1:], 1e-39*Xsec_vtau_tau_mu_coh_Ar_adKN[1:]/Energy_vtau_tau_mu_coh_Ar_adKN[1:], color=col[4], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-56, 1e-40])
ax.set_xlim([1e-3,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.text(4e-2, 1e-48, r'$\nu_\mu \to \nu_e e^{+} \mu^{-}$', color=col[0], rotation=80, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])
ax.text(4e-3, 8e-45, r'$\nu_\mu \to \nu_\mu e^{+} e^{-}$', color=col[1], rotation=25, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])
ax.text(5e-1, 9e-47, r'$\nu_\mu \to \nu_\mu \mu^{+} \mu^{-}$', color=col[2], rotation=50, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])
ax.text(20, 1e-52, r'$\nu_\mu \to \nu_\mu \tau^{+} \tau^{-}$', color=col[3], rotation=75, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])
ax.text(2, 5e-49, r'$\nu_\mu \to \nu_\tau \tau^{+} \mu^{-}$', color=col[4], rotation=65, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])

ax.set_title(r'Argon $^{40}$Ar')
ax.set_ylabel(r'Cross Section/$E_\nu$ [cm$^2$ GeV$^{-1}$]')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(loc= 'lower right', fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/40Argon_Xsection_all_processes.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/40Argon_Xsection_all_processes.png', transparent=False, bbox_inches='tight')

# %%
fig = plt.figure()
ax = fig.add_subplot()

####################################################################################################################
####################################### x-axis: GeV y-axis: cm^2/GeV ###############################################
####################################################################################################################
col = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
ls = ['-', '--', ':', '-.', (0,(8, 2, 3, 2))]

########################### Add background to introduce the Form Factor Labels #####################################
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_WS[1:]/Enu[1:], color='black', ls=ls[0], lw=2, label='WS', zorder=-100, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_H1[1:]/Enu[1:], color='black', ls=ls[1], lw=2, label='Helm [v1]', zorder=-100,  path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_H2[1:]/Enu[1:], color='black', ls=ls[2], lw=2, label='Helm [v2]', zorder=-100, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_KN[1:]/Enu[1:], color='black', ls=ls[3], lw=2, label='KN', zorder=-100, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_adKN[1:]/Enu[1:], color='black', ls=ls[4], lw=2, label='(ad.) KN', zorder=-100, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

############################# Cross Sections for the process: ve -> ve e+ e- #######################################
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_WS[1:]/Enu[1:], color=col[0], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_H1[1:]/Enu[1:], color=col[0], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_H2[1:]/Enu[1:], color=col[0], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_KN[1:]/Enu[1:], color=col[0], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_e_e_coh_W_adKN[1:]/Enu[1:], color=col[0], ls=ls[4], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

############################# Cross Sections for the process: ve -> ve mu+ mu- #######################################
ax.plot(Enu[1:], 1e-39*Xsec_ve_mu_mu_coh_W_WS[1:]/Enu[1:], color=col[1], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_mu_mu_coh_W_H1[1:]/Enu[1:], color=col[1], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_mu_mu_coh_W_H2[1:]/Enu[1:], color=col[1], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_mu_mu_coh_W_KN[1:]/Enu[1:], color=col[1], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_ve_mu_mu_coh_W_adKN[1:]/Enu[1:], color=col[1], ls=ls[4], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

############################# Cross Sections for the process: ve -> vmu mu+ e- #######################################
ax.plot(Enu[1:], 1e-39*Xsec_vmu_mu_e_coh_W_WS[1:]/Enu[1:], color=col[2], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_vmu_mu_e_coh_W_H1[1:]/Enu[1:], color=col[2], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_vmu_mu_e_coh_W_H2[1:]/Enu[1:], color=col[2], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_vmu_mu_e_coh_W_KN[1:]/Enu[1:], color=col[2], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_vmu_mu_e_coh_W_adKN[1:]/Enu[1:], color=col[2], ls=ls[4], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

############################# Cross Sections for the process: ve -> vtau tau+ e- #######################################
ax.plot(Enu[1:], 1e-39*Xsec_vtau_tau_e_coh_W_WS[1:]/Enu[1:], color=col[3], ls=ls[0], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_vtau_tau_e_coh_W_H1[1:]/Enu[1:], color=col[3], ls=ls[1], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_vtau_tau_e_coh_W_H2[1:]/Enu[1:], color=col[3], ls=ls[2], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_vtau_tau_e_coh_W_KN[1:]/Enu[1:], color=col[3], ls=ls[3], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(Enu[1:], 1e-39*Xsec_vtau_tau_e_coh_W_adKN[1:]/Enu[1:], color=col[3], ls=ls[4], lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-56, 1e-39])
ax.set_xlim([1e-3,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.text(2e-3, 4e-46, r'$\nu_e \to \nu_e e^{+} e^{-}$', color=col[0], rotation=45, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])
ax.text(0.8, 2e-45, r'$\nu_e \to \nu_e \mu^{+} \mu^{-}$', color=col[1], rotation=35, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])
ax.text(4e-2, 9e-47, r'$\nu_e \to \nu_\mu \mu^{+} e^{-}$', color=col[2], rotation=65, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])
ax.text(5, 1e-52, r'$\nu_e \to \nu_\tau \tau^{+} e^{-}$', color=col[3], rotation=75, fontsize=30, path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])

ax.set_title(r'Tungsten $^{184}$W')
ax.set_ylabel(r'Cross Section/$E_\nu$ [cm$^2$ GeV$^{-1}$]')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(loc= 'lower right', fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/184Tungsten_Xsection_all_processes.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/184Tungsten_Xsection_all_processes.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_\mu \to \nu_e e^{+} \mu^{-}$ process

# %%
def NoNull_Xsec(Xsec, Energy):
    new_Xsec = Xsec[Xsec!=0]
    new_Energy = Energy[Xsec!=0]
    return new_Energy, new_Xsec

New_Energy_ve_e_mu_coh_Ar_3pF, New_Xsec_ve_e_mu_coh_Ar_3pF = NoNull_Xsec(Xsec_ve_e_mu_coh_Ar_3pF, Energy_ve_e_mu_coh_Ar_3pF)
New_Energy_ve_e_mu_coh_Ar_Helm, New_Xsec_ve_e_mu_coh_Ar_Helm = NoNull_Xsec(Xsec_ve_e_mu_coh_Ar_Helm, Energy_ve_e_mu_coh_Ar_Helm)
New_Energy_ve_e_mu_coh_Ar_KN, New_Xsec_ve_e_mu_coh_Ar_KN = NoNull_Xsec(Xsec_ve_e_mu_coh_Ar_KN, Energy_ve_e_mu_coh_Ar_KN)
New_Energy_ve_e_mu_coh_Ar_adKN, New_Xsec_ve_e_mu_coh_Ar_adKN = NoNull_Xsec(Xsec_ve_e_mu_coh_Ar_adKN, Energy_ve_e_mu_coh_Ar_adKN)

Uncertainty_ve_e_mu_coh_Ar_Helm = 100*np.abs(1 - New_Xsec_ve_e_mu_coh_Ar_Helm/New_Xsec_ve_e_mu_coh_Ar_3pF)
Uncertainty_ve_e_mu_coh_Ar_KN = 100*np.abs(1 - New_Xsec_ve_e_mu_coh_Ar_KN/New_Xsec_ve_e_mu_coh_Ar_3pF)
Uncertainty_ve_e_mu_coh_Ar_adKN = 100*np.abs(1 - New_Xsec_ve_e_mu_coh_Ar_adKN/New_Xsec_ve_e_mu_coh_Ar_3pF)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Energy_ve_e_mu_coh_Ar_3pF, Uncertainty_ve_e_mu_coh_Ar_Helm, label=r'Helm', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_ve_e_mu_coh_Ar_3pF, Uncertainty_ve_e_mu_coh_Ar_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_ve_e_mu_coh_Ar_3pF, Uncertainty_ve_e_mu_coh_Ar_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_xscale('log')
ax.set_ylim([0, 18])
ax.set_xlim([1e-1,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_\mu \to \nu_e e^{+} \mu^{-}$ [Argon $^{40}$Ar]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/40Argon_Uncertainty_ve_e_mu_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/40Argon_Uncertainty_ve_e_mu_coh.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_\mu \to \nu_\mu e^{+} e^{-}$ process

# %%
New_Energy_vmu_e_e_coh_Ar_3pF, New_Xsec_vmu_e_e_coh_Ar_3pF = NoNull_Xsec(Xsec_vmu_e_e_coh_Ar_3pF, Energy_vmu_e_e_coh_Ar_3pF)
New_Energy_vmu_e_e_coh_Ar_Helm, New_Xsec_vmu_e_e_coh_Ar_Helm = NoNull_Xsec(Xsec_vmu_e_e_coh_Ar_Helm, Energy_vmu_e_e_coh_Ar_Helm)
New_Energy_vmu_e_e_coh_Ar_KN, New_Xsec_vmu_e_e_coh_Ar_KN = NoNull_Xsec(Xsec_vmu_e_e_coh_Ar_KN, Energy_vmu_e_e_coh_Ar_KN)
New_Energy_vmu_e_e_coh_Ar_adKN, New_Xsec_vmu_e_e_coh_Ar_adKN = NoNull_Xsec(Xsec_vmu_e_e_coh_Ar_adKN, Energy_vmu_e_e_coh_Ar_adKN)

Uncertainty_vmu_e_e_coh_Ar_Helm = 100*np.abs(1 - New_Xsec_vmu_e_e_coh_Ar_Helm/New_Xsec_vmu_e_e_coh_Ar_3pF)
Uncertainty_vmu_e_e_coh_Ar_KN = 100*np.abs(1 - New_Xsec_vmu_e_e_coh_Ar_KN/New_Xsec_vmu_e_e_coh_Ar_3pF)
Uncertainty_vmu_e_e_coh_Ar_adKN = 100*np.abs(1 - New_Xsec_vmu_e_e_coh_Ar_adKN/New_Xsec_vmu_e_e_coh_Ar_3pF)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Energy_vmu_e_e_coh_Ar_3pF, Uncertainty_vmu_e_e_coh_Ar_Helm, label=r'Helm', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_vmu_e_e_coh_Ar_3pF, Uncertainty_vmu_e_e_coh_Ar_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_vmu_e_e_coh_Ar_3pF, Uncertainty_vmu_e_e_coh_Ar_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_xscale('log')
ax.set_ylim([0, 7])
ax.set_xlim([1e-3,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_\mu \to \nu_\mu e^{+} e^{-}$ [Argon $^{40}$Ar]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/40Argon_Uncertainty_vmu_e_e_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/40Argon_Uncertainty_vmu_e_e_coh.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_\mu \to \nu_\mu \mu^{+} \mu^{-}$ process

# %%
New_Energy_vmu_mu_mu_coh_Ar_3pF, New_Xsec_vmu_mu_mu_coh_Ar_3pF = NoNull_Xsec(Xsec_vmu_mu_mu_coh_Ar_3pF, Energy_vmu_mu_mu_coh_Ar_3pF)
New_Energy_vmu_mu_mu_coh_Ar_Helm, New_Xsec_vmu_mu_mu_coh_Ar_Helm = NoNull_Xsec(Xsec_vmu_mu_mu_coh_Ar_Helm, Energy_vmu_mu_mu_coh_Ar_Helm)
New_Energy_vmu_mu_mu_coh_Ar_KN, New_Xsec_vmu_mu_mu_coh_Ar_KN = NoNull_Xsec(Xsec_vmu_mu_mu_coh_Ar_KN, Energy_vmu_mu_mu_coh_Ar_KN)
New_Energy_vmu_mu_mu_coh_Ar_adKN, New_Xsec_vmu_mu_mu_coh_Ar_adKN = NoNull_Xsec(Xsec_vmu_mu_mu_coh_Ar_adKN, Energy_vmu_mu_mu_coh_Ar_adKN)

Uncertainty_vmu_mu_mu_coh_Ar_Helm = 100*np.abs(1 - New_Xsec_vmu_mu_mu_coh_Ar_Helm/New_Xsec_vmu_mu_mu_coh_Ar_3pF)
Uncertainty_vmu_mu_mu_coh_Ar_KN = 100*np.abs(1 - New_Xsec_vmu_mu_mu_coh_Ar_KN/New_Xsec_vmu_mu_mu_coh_Ar_3pF)
Uncertainty_vmu_mu_mu_coh_Ar_adKN = 100*np.abs(1 - New_Xsec_vmu_mu_mu_coh_Ar_adKN/New_Xsec_vmu_mu_mu_coh_Ar_3pF)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Energy_vmu_mu_mu_coh_Ar_3pF, Uncertainty_vmu_mu_mu_coh_Ar_Helm, label=r'Helm', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_vmu_mu_mu_coh_Ar_3pF, Uncertainty_vmu_mu_mu_coh_Ar_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_vmu_mu_mu_coh_Ar_3pF, Uncertainty_vmu_mu_mu_coh_Ar_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_xscale('log')
ax.set_ylim([0, 65])
ax.set_xlim([2e-1,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_\mu \to \nu_\mu \mu^{+} \mu^{-}$ [Argon $^{40}$Ar]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/40Argon_Uncertainty_vmu_mu_mu_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/40Argon_Uncertainty_vmu_mu_mu_coh.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_\mu \to \nu_\mu \tau^{+} \tau^{-}$ process

# %%
New_Energy_vmu_tau_tau_coh_Ar_3pF, New_Xsec_vmu_tau_tau_coh_Ar_3pF = NoNull_Xsec(Xsec_vmu_tau_tau_coh_Ar_3pF, Energy_vmu_tau_tau_coh_Ar_3pF)
New_Energy_vmu_tau_tau_coh_Ar_Helm, New_Xsec_vmu_tau_tau_coh_Ar_Helm = NoNull_Xsec(Xsec_vmu_tau_tau_coh_Ar_Helm, Energy_vmu_tau_tau_coh_Ar_Helm)
New_Energy_vmu_tau_tau_coh_Ar_KN, New_Xsec_vmu_tau_tau_coh_Ar_KN = NoNull_Xsec(Xsec_vmu_tau_tau_coh_Ar_KN, Energy_vmu_tau_tau_coh_Ar_KN)
New_Energy_vmu_tau_tau_coh_Ar_adKN, New_Xsec_vmu_tau_tau_coh_Ar_adKN = NoNull_Xsec(Xsec_vmu_tau_tau_coh_Ar_adKN, Energy_vmu_tau_tau_coh_Ar_adKN)

Uncertainty_vmu_tau_tau_coh_Ar_Helm = 100*np.abs(1 - New_Xsec_vmu_tau_tau_coh_Ar_Helm/New_Xsec_vmu_tau_tau_coh_Ar_3pF)
Uncertainty_vmu_tau_tau_coh_Ar_KN = 100*np.abs(1 - New_Xsec_vmu_tau_tau_coh_Ar_KN/New_Xsec_vmu_tau_tau_coh_Ar_3pF)
Uncertainty_vmu_tau_tau_coh_Ar_adKN = 100*np.abs(1 - New_Xsec_vmu_tau_tau_coh_Ar_adKN/New_Xsec_vmu_tau_tau_coh_Ar_3pF)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Energy_vmu_tau_tau_coh_Ar_3pF, Uncertainty_vmu_tau_tau_coh_Ar_Helm, label=r'Helm', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_vmu_tau_tau_coh_Ar_3pF, Uncertainty_vmu_tau_tau_coh_Ar_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_vmu_tau_tau_coh_Ar_3pF, Uncertainty_vmu_tau_tau_coh_Ar_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-3, 1e8])
ax.set_xlim([3,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_\mu \to \nu_\mu \tau^{+} \tau^{-}$ [Argon $^{40}$Ar]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/40Argon_Uncertainty_vmu_tau_tau_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/40Argon_Uncertainty_vmu_tau_tau_coh.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_\mu \to \nu_\tau \tau^{+} \mu^{-}$ process

# %%
New_Energy_vtau_tau_mu_coh_Ar_3pF, New_Xsec_vtau_tau_mu_coh_Ar_3pF = NoNull_Xsec(Xsec_vtau_tau_mu_coh_Ar_3pF, Energy_vtau_tau_mu_coh_Ar_3pF)
New_Energy_vtau_tau_mu_coh_Ar_Helm, New_Xsec_vtau_tau_mu_coh_Ar_Helm = NoNull_Xsec(Xsec_vtau_tau_mu_coh_Ar_Helm, Energy_vtau_tau_mu_coh_Ar_Helm)
New_Energy_vtau_tau_mu_coh_Ar_KN, New_Xsec_vtau_tau_mu_coh_Ar_KN = NoNull_Xsec(Xsec_vtau_tau_mu_coh_Ar_KN, Energy_vtau_tau_mu_coh_Ar_KN)
New_Energy_vtau_tau_mu_coh_Ar_adKN, New_Xsec_vtau_tau_mu_coh_Ar_adKN = NoNull_Xsec(Xsec_vtau_tau_mu_coh_Ar_adKN, Energy_vtau_tau_mu_coh_Ar_adKN)

Uncertainty_vtau_tau_mu_coh_Ar_Helm = 100*np.abs(1 - New_Xsec_vtau_tau_mu_coh_Ar_Helm/New_Xsec_vtau_tau_mu_coh_Ar_3pF)
Uncertainty_vtau_tau_mu_coh_Ar_KN = 100*np.abs(1 - New_Xsec_vtau_tau_mu_coh_Ar_KN/New_Xsec_vtau_tau_mu_coh_Ar_3pF)
Uncertainty_vtau_tau_mu_coh_Ar_adKN = 100*np.abs(1 - New_Xsec_vtau_tau_mu_coh_Ar_adKN/New_Xsec_vtau_tau_mu_coh_Ar_3pF)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Energy_vtau_tau_mu_coh_Ar_3pF, Uncertainty_vtau_tau_mu_coh_Ar_Helm, label=r'Helm', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_vtau_tau_mu_coh_Ar_3pF, Uncertainty_vtau_tau_mu_coh_Ar_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Energy_vtau_tau_mu_coh_Ar_3pF, Uncertainty_vtau_tau_mu_coh_Ar_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([1e-1, 1e8])
ax.set_xlim([1.9,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_\mu \to \nu_\tau \tau^{+} \mu^{-}$ [Argon $^{40}$Ar]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/40Argon_Uncertainty_vtau_tau_mu_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/40Argon_Uncertainty_vtau_tau_mu_coh.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_e \to \nu_e e^{+} e^{-}$ process

# %%
New_Enu_ve_e_e_coh_W, New_Xsec_ve_e_e_coh_W_WS = NoNull_Xsec(Xsec_ve_e_e_coh_W_WS, Enu)
New_Enu_ve_e_e_coh_W, New_Xsec_ve_e_e_coh_W_H1 = NoNull_Xsec(Xsec_ve_e_e_coh_W_H1, Enu)
New_Enu_ve_e_e_coh_W, New_Xsec_ve_e_e_coh_W_H2 = NoNull_Xsec(Xsec_ve_e_e_coh_W_H2, Enu)
New_Enu_ve_e_e_coh_W, New_Xsec_ve_e_e_coh_W_KN = NoNull_Xsec(Xsec_ve_e_e_coh_W_KN, Enu)
New_Enu_ve_e_e_coh_W, New_Xsec_ve_e_e_coh_W_adKN = NoNull_Xsec(Xsec_ve_e_e_coh_W_adKN, Enu)


Uncertainty_ve_e_e_coh_W_Helmv1 = 100*np.abs(1 - New_Xsec_ve_e_e_coh_W_H1/New_Xsec_ve_e_e_coh_W_WS)
Uncertainty_ve_e_e_coh_W_Helmv2 = 100*np.abs(1 - New_Xsec_ve_e_e_coh_W_H2/New_Xsec_ve_e_e_coh_W_WS)
Uncertainty_ve_e_e_coh_W_KN = 100*np.abs(1 - New_Xsec_ve_e_e_coh_W_KN/New_Xsec_ve_e_e_coh_W_WS)
Uncertainty_ve_e_e_coh_W_adKN = 100*np.abs(1 - New_Xsec_ve_e_e_coh_W_adKN/New_Xsec_ve_e_e_coh_W_WS)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Enu_ve_e_e_coh_W, Uncertainty_ve_e_e_coh_W_Helmv1, label=r'Helm [v1]', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_ve_e_e_coh_W, Uncertainty_ve_e_e_coh_W_Helmv2, label=r'Helm [v2]', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_ve_e_e_coh_W, Uncertainty_ve_e_e_coh_W_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_ve_e_e_coh_W, Uncertainty_ve_e_e_coh_W_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])


ax.set_xscale('log')
ax.set_ylim([0, 6.5])
ax.set_xlim([1e-3,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_e \to \nu_e e^{+} e^{-}$ [Tungsten $^{184}$W]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/184Tungsten_Uncertainty_ve_e_e_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/184Tungsten_Uncertainty_ve_e_e_coh.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_e \to \nu_e \mu^{+} \mu^{-}$ process

# %%
New_Enu_ve_mu_mu_coh_W, New_Xsec_ve_mu_mu_coh_W_WS = NoNull_Xsec(Xsec_ve_mu_mu_coh_W_WS, Enu)
New_Enu_ve_mu_mu_coh_W, New_Xsec_ve_mu_mu_coh_W_H1 = NoNull_Xsec(Xsec_ve_mu_mu_coh_W_H1, Enu)
New_Enu_ve_mu_mu_coh_W, New_Xsec_ve_mu_mu_coh_W_H2 = NoNull_Xsec(Xsec_ve_mu_mu_coh_W_H2, Enu)
New_Enu_ve_mu_mu_coh_W, New_Xsec_ve_mu_mu_coh_W_KN = NoNull_Xsec(Xsec_ve_mu_mu_coh_W_KN, Enu)
New_Enu_ve_mu_mu_coh_W, New_Xsec_ve_mu_mu_coh_W_adKN = NoNull_Xsec(Xsec_ve_mu_mu_coh_W_adKN, Enu)


Uncertainty_ve_mu_mu_coh_W_Helmv1 = 100*np.abs(1 - New_Xsec_ve_mu_mu_coh_W_H1/New_Xsec_ve_mu_mu_coh_W_WS)
Uncertainty_ve_mu_mu_coh_W_Helmv2 = 100*np.abs(1 - New_Xsec_ve_mu_mu_coh_W_H2/New_Xsec_ve_mu_mu_coh_W_WS)
Uncertainty_ve_mu_mu_coh_W_KN = 100*np.abs(1 - New_Xsec_ve_mu_mu_coh_W_KN/New_Xsec_ve_mu_mu_coh_W_WS)
Uncertainty_ve_mu_mu_coh_W_adKN = 100*np.abs(1 - New_Xsec_ve_mu_mu_coh_W_adKN/New_Xsec_ve_mu_mu_coh_W_WS)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Enu_ve_mu_mu_coh_W, Uncertainty_ve_mu_mu_coh_W_Helmv1, label=r'Helm [v1]', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_ve_mu_mu_coh_W, Uncertainty_ve_mu_mu_coh_W_Helmv2, label=r'Helm [v2]', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_ve_mu_mu_coh_W, Uncertainty_ve_mu_mu_coh_W_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_ve_mu_mu_coh_W, Uncertainty_ve_mu_mu_coh_W_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_xscale('log')
ax.set_ylim([0, 85])
ax.set_xlim([1e-1,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_e \to \nu_e \mu^{+} \mu^{-}$ [Tungsten $^{184}$W]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/184Tungsten_Uncertainty_ve_mu_mu_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/184Tungsten_Uncertainty_ve_mu_mu_coh.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_e \to \nu_\mu \mu^{+} e^{-}$ process

# %%
New_Enu_vmu_mu_e_coh_W, New_Xsec_vmu_mu_e_coh_W_WS = NoNull_Xsec(Xsec_vmu_mu_e_coh_W_WS, Enu)
New_Enu_vmu_mu_e_coh_W, New_Xsec_vmu_mu_e_coh_W_H1 = NoNull_Xsec(Xsec_vmu_mu_e_coh_W_H1, Enu)
New_Enu_vmu_mu_e_coh_W, New_Xsec_vmu_mu_e_coh_W_H2 = NoNull_Xsec(Xsec_vmu_mu_e_coh_W_H2, Enu)
New_Enu_vmu_mu_e_coh_W, New_Xsec_vmu_mu_e_coh_W_KN = NoNull_Xsec(Xsec_vmu_mu_e_coh_W_KN, Enu)
New_Enu_vmu_mu_e_coh_W, New_Xsec_vmu_mu_e_coh_W_adKN = NoNull_Xsec(Xsec_vmu_mu_e_coh_W_adKN, Enu)


Uncertainty_vmu_mu_e_coh_W_Helmv1 = 100*np.abs(1 - New_Xsec_vmu_mu_e_coh_W_H1/New_Xsec_vmu_mu_e_coh_W_WS)
Uncertainty_vmu_mu_e_coh_W_Helmv2 = 100*np.abs(1 - New_Xsec_vmu_mu_e_coh_W_H2/New_Xsec_vmu_mu_e_coh_W_WS)
Uncertainty_vmu_mu_e_coh_W_KN = 100*np.abs(1 - New_Xsec_vmu_mu_e_coh_W_KN/New_Xsec_vmu_mu_e_coh_W_WS)
Uncertainty_vmu_mu_e_coh_W_adKN = 100*np.abs(1 - New_Xsec_vmu_mu_e_coh_W_adKN/New_Xsec_vmu_mu_e_coh_W_WS)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Enu_vmu_mu_e_coh_W, Uncertainty_vmu_mu_e_coh_W_Helmv1, label=r'Helm [v1]', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_vmu_mu_e_coh_W, Uncertainty_vmu_mu_e_coh_W_Helmv2, label=r'Helm [v2]', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_vmu_mu_e_coh_W, Uncertainty_vmu_mu_e_coh_W_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_vmu_mu_e_coh_W, Uncertainty_vmu_mu_e_coh_W_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_xscale('log')
ax.set_ylim([0, 50])
ax.set_xlim([1e-1,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_e \to \nu_\mu \mu^{+} e^{-}$ [Tungsten $^{184}$W]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/184Tungsten_Uncertainty_vmu_mu_e_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/184Tungsten_Uncertainty_vmu_mu_e_coh.png', transparent=False, bbox_inches='tight')

# %% [markdown]
# # Uncertainties on the $\nu_e \to \nu_\tau \tau^{+} e^{-}$ process

# %%
New_Enu_vtau_tau_e_coh_W, New_Xsec_vtau_tau_e_coh_W_WS = NoNull_Xsec(Xsec_vtau_tau_e_coh_W_WS, Enu)
New_Enu_vtau_tau_e_coh_W, New_Xsec_vtau_tau_e_coh_W_H1 = NoNull_Xsec(Xsec_vtau_tau_e_coh_W_H1, Enu)
New_Enu_vtau_tau_e_coh_W, New_Xsec_vtau_tau_e_coh_W_H2 = NoNull_Xsec(Xsec_vtau_tau_e_coh_W_H2, Enu)
New_Enu_vtau_tau_e_coh_W, New_Xsec_vtau_tau_e_coh_W_KN = NoNull_Xsec(Xsec_vtau_tau_e_coh_W_KN, Enu)
New_Enu_vtau_tau_e_coh_W, New_Xsec_vtau_tau_e_coh_W_adKN = NoNull_Xsec(Xsec_vtau_tau_e_coh_W_adKN, Enu)


Uncertainty_vtau_tau_e_coh_W_Helmv1 = 100*np.abs(1 - New_Xsec_vtau_tau_e_coh_W_H1/New_Xsec_vtau_tau_e_coh_W_WS)
Uncertainty_vtau_tau_e_coh_W_Helmv2 = 100*np.abs(1 - New_Xsec_vtau_tau_e_coh_W_H2/New_Xsec_vtau_tau_e_coh_W_WS)
Uncertainty_vtau_tau_e_coh_W_KN = 100*np.abs(1 - New_Xsec_vtau_tau_e_coh_W_KN/New_Xsec_vtau_tau_e_coh_W_WS)
Uncertainty_vtau_tau_e_coh_W_adKN = 100*np.abs(1 - New_Xsec_vtau_tau_e_coh_W_adKN/New_Xsec_vtau_tau_e_coh_W_WS)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(New_Enu_vtau_tau_e_coh_W, Uncertainty_vtau_tau_e_coh_W_Helmv1, label=r'Helm [v1]', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_vtau_tau_e_coh_W, Uncertainty_vtau_tau_e_coh_W_Helmv2, label=r'Helm [v2]', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_vtau_tau_e_coh_W, Uncertainty_vtau_tau_e_coh_W_KN, label=r'KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])
ax.plot(New_Enu_vtau_tau_e_coh_W, Uncertainty_vtau_tau_e_coh_W_adKN, label=r'(ad.) KN', lw=2, path_effects=[pe.Stroke(linewidth=3, foreground='k'), pe.Normal()])

ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim([3e-4, 3e7])
ax.set_xlim([1e0,1e4])

ax.xaxis.grid(True, which='major', ls=ls[0], alpha=0.35)
ax.yaxis.grid(True, which='major', ls=ls[0], alpha=0.35)

ax.set_title(r'$\nu_e \to \nu_\tau \tau^{+} e^{-}$ [Tungsten $^{184}$W]')
ax.set_ylabel(r'$\Delta \sigma (E_\nu) [\%]$')
ax.set_xlabel(r'Neutrino Energy $E_\nu$ [GeV]')
ax.legend(fontsize=25, frameon=False, framealpha=1, edgecolor='k', fancybox=True)

plt.savefig('../Plots/Figures_PDF/184Tungsten_Uncertainty_vtau_tau_e_coh.pdf', transparent=False, bbox_inches='tight')
plt.savefig('../Plots/Figures_PNG/184Tungsten_Uncertainty_vtau_tau_e_coh.png', transparent=False, bbox_inches='tight')
